# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
from matplotlib import pyplot as plt
import os
# %matplotlib inline

# %%
ls
# Out:
# nba/  nba capstone 3.ipynb  nba project.ipynb  nba project new.ipynb  README.md

# %%
os.chdir('nba')

# %% [markdown]
# ### Reading data

# %%
salaries=pd.read_csv('NBASalaries1990to2016.csv')

# %%
s15=pd.read_csv('nba_data/2015stats.csv')

# %%
s14=pd.read_csv('nba_data/2014stats.csv')

# %%
s13=pd.read_csv('nba_data/2013stats.csv')

# %%
s12=pd.read_csv('nba_data/2012stats.csv')

# %%
s11=pd.read_csv('nba_data/2011stats.csv')

# %%
s10=pd.read_csv('nba_data/2010stats.csv')

# %%
a15=pd.read_csv('nba_data/advanced2015.csv')

# %%
a14=pd.read_csv('nba_data/advanced2014.csv')

# %%
a13=pd.read_csv('nba_data/advanced2013.csv')

# %%
a12=pd.read_csv('nba_data/advanced2012.csv')

# %%
a11=pd.read_csv('nba_data/advanced2011.csv')

# %%
a10=pd.read_csv('nba_data/advanced2010.csv')

# %%
s15['Year']=2015

# %%
s14['Year']=2014

# %%
s13['Year']=2013

# %%
s12['Year']=2012

# %%
s11['Year']=2011

# %%
s10['Year']=2010

# %%
a15['Year']=2015

# %%
a14['Year']=2014

# %%
a13['Year']=2013

# %%
a12['Year']=2012

# %%
a11['Year']=2011

# %%
a10['Year']=2010

# %% [markdown]
# ### Combining dataframe to concat

# %%
statsdf=[s15,s14,s13,s12,s11,s10]

# %%
advancedf=[a15,a14,a13,a12,a11,a10]

# %%
stats=pd.concat(statsdf)

# %%
advancedstats=pd.concat(advancedf)

# %% [markdown]
# ### Checking and dealing with missing values

# %%
stats.isnull().sum()
# Out:
# Rk          0
# Player      0
# Pos         0
# Age         0
# Tm          0
# G           0
# GS          0
# MP          0
# FG          0
# FGA         0
# FG%        19
# 3P          0
# 3PA         0
# 3P%       575
# 2P          0
# 2PA         0
# 2P%        26
# eFG%       19
# FT          0
# FTA         0
# FT%       154
# ORB         0
# DRB         0
# TRB         0
# AST         0
# STL         0
# BLK         0
# TOV         0
# PF          0
# PTS         0
# Year        0
# dtype: int64

# %%
stats[pd.isnull(stats['3P%'])][['Player','3P','3PA','3P%']]
# Out:
#                           Player  3P  3PA  3P%
# 3          Jeff Adrien\adrieje01   0    0  NaN
# 7        Alexis Ajinca\ajincal01   0    0  NaN
# 9         Cole Aldrich\aldrico01   0    0  NaN
# 11         Lavoy Allen\allenla01   0    0  NaN
# 15        Lou Amundson\amundlo01   0    0  NaN
# 23        Joel Anthony\anthojo01   0    0  NaN
# 27            Omer Asik\asikom01   0    0  NaN
# 31          Jeff Ayres\pendeje02   0    0  NaN
# 33    Cameron Bairstow\bairsca01   0    0  NaN
# 51    Jerrelle Benimon\benimje01   0    0  NaN
# 54         Sim Bhullar\bhullsi01   0    0  NaN
# 55     Bismack Biyombo\biyombi01   0    0  NaN
# 58         Tarik Black\blackta01   0    0  NaN
# 59        DeJuan Blair\blairde01   0    0  NaN
# 64        Andrew Bogut\bogutan01   0    0  NaN
# 67       Carlos Boozer\boozeca01   0    0  NaN
# 98        Clint Capela\capelca01   0    0  NaN
# 106     Tyson Chandler\chandty01   0    0  NaN
# 122        Jack Cooley\cooleja01   0    0  NaN
# ...

# %%
stats[pd.isnull(stats['FG%'])][['Player','FG','FGA','FG%']]
# Out:
#                          Player  FG  FGA  FG%
# 51   Jerrelle Benimon\benimje01   0    0  NaN
# 590      Ronny Turiaf\turiaro01   0    0  NaN
# 19       Lou Amundson\amundlo01   0    0  NaN
# 83      Ronnie Brewer\brewero02   0    0  NaN
# 121    Josh Childress\childjo01   0    0  NaN
# 147        Seth Curry\curryse01   0    0  NaN
# 247   Justin Hamilton\hamilju01   0    0  NaN
# 505       Chris Smith\smithch05   0    0  NaN
# 565    Jarvis Varnado\varnaja01   0    0  NaN
# 89       Matt Carroll\carroma01   0    0  NaN
# 253      Damion James\jamesda01   0    0  NaN
# 468      Donald Sloan\sloando01   0    0  NaN
# 520      Jeremy Tyler\tylerje01   0    0  NaN
# 360        Gani Lawal\lawalga01   0    0  NaN
# 505     Brian Skinner\skinnbr01   0    0  NaN
# 592  Hassan Whiteside\whiteha01   0    0  NaN
# 119     JamesOn Curry\curryja01   0    0  NaN
# 305      Dwayne Jones\jonesdw02   0    0  NaN
# 312          Coby Karl\karlco01   0    0  NaN

# %%
stats[pd.isnull(stats['FT%'])][['Player','FT','FTA','FT%']]
# Out:
#                             Player  FT  FTA  FT%
# 51      Jerrelle Benimon\benimje01   0    0  NaN
# 54           Sim Bhullar\bhullsi01   0    0  NaN
# 91         Bruno Caboclo\cabocbr01   0    0  NaN
# 109  Patrick Christopher\chrispa01   0    0  NaN
# 115        Victor Claver\clavevi01   0    0  NaN
# 134           Seth Curry\curryse01   0    0  NaN
# 142         Luigi Datome\datomlu01   0    0  NaN
# 150        Andre Dawkins\dawkian01   0    0  NaN
# 195      Jamaal Franklin\frankja01   0    0  NaN
# 232       JaMychal Green\greenja01   0    0  NaN
# 243      Jordan Hamilton\hamiljo02   0    0  NaN
# 299        Grant Jerrett\jerregr01   0    0  NaN
# 345            Malcolm Lee\leema01   0    0  NaN
# 357          Kalin Lucas\lucaska01   0    0  NaN
# 364       Cartier Martin\martica01   0    0  NaN
# 386            Gal Mekel\mekelga01   0    0  NaN
# 392        Darius Miller\milleda01   0    0  NaN
# 396        Quincy Miller\millequ01   0    0  NaN
# ...

# %%
stats[["3P%",'FT%','FG%','2P%','eFG%']]=stats[["3P%",'FT%','FG%','2P%','eFG%']].fillna(0)

# %%
stats.isnull().sum()
# Out:
# Rk        0
# Player    0
# Pos       0
# Age       0
# Tm        0
# G         0
# GS        0
# MP        0
# FG        0
# FGA       0
# FG%       0
# 3P        0
# 3PA       0
# 3P%       0
# 2P        0
# 2PA       0
# 2P%       0
# eFG%      0
# FT        0
# FTA       0
# FT%       0
# ORB       0
# DRB       0
# TRB       0
# AST       0
# STL       0
# BLK       0
# TOV       0
# PF        0
# PTS       0
# Year      0
# dtype: int64

# %%
advancedstats.isnull().sum()
# Out:
# Rk                0
# Player            0
# Pos               0
# Age               0
# Tm                0
# G                 0
# MP                0
# PER               2
# TS%              19
# 3PAr             19
# FTr              19
# ORB%              2
# DRB%              2
# TRB%              2
# AST%              2
# STL%              2
# BLK%              2
# TOV%             14
# USG%              2
# Unnamed: 19    3589
# OWS               0
# DWS               0
# WS                0
# WS/48             2
# Unnamed: 24    3589
# OBPM              0
# DBPM              0
# BPM               0
# VORP              0
# Year              0
# dtype: int64

# %%
advancedstats=advancedstats.drop(['Unnamed: 19','Unnamed: 24'],1)

# %%
pd.set_option('max_columns',1000)

# %%
pd.set_option('max_rows',100)

# %%
advancedstats[['TS%','3PAr','FTr']]=advancedstats[['TS%','3PAr','FTr']].fillna(0)

# %%
advancedstats.isnull().sum()
# Out:
# Rk         0
# Player     0
# Pos        0
# Age        0
# Tm         0
# G          0
# MP         0
# PER        2
# TS%        0
# 3PAr       0
# FTr        0
# ORB%       2
# DRB%       2
# TRB%       2
# AST%       2
# STL%       2
# BLK%       2
# TOV%      14
# USG%       2
# OWS        0
# DWS        0
# WS         0
# WS/48      2
# OBPM       0
# DBPM       0
# BPM        0
# VORP       0
# Year       0
# dtype: int64

# %% [markdown]
# minimum data missing after the columns are dropped

# %%
advancedstats.dropna(inplace=True)

# %%
advancedstats.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'MP', 'PER', 'TS%', '3PAr',
#        'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%',
#        'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP', 'Year'],
#       dtype='object')

# %%
stats.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Year'],
#       dtype='object')

# %%
result=pd.merge(stats,advancedstats,how='inner',on=['Year','Player','Rk','Pos','Age','Tm','G','MP'])

# %%
stats.shape
# Out:
# (3589, 31)

# %%
advancedstats.shape
# Out:
# (3575, 28)

# %%
result.shape
# Out:
# (3575, 51)

# %%
result.isnull().values.any()
# Out:
# False

# %%
result.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Year',
#        'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%',
#        'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM',
#        'BPM', 'VORP'],
#       dtype='object')

# %% [markdown]
# ### Prepare data for merge

# %%
result.Player.head()
# Out:
# 0         Quincy Acy\acyqu01
# 1     Jordan Adams\adamsjo01
# 2     Steven Adams\adamsst01
# 3      Jeff Adrien\adrieje01
# 4    Arron Afflalo\afflaar01
# Name: Player, dtype: object

# %%
result[['Player','ID']]=result['Player'].str.split(r'\\', expand=True)
result.head()
# Out:
#    Rk         Player Pos  Age   Tm   G  GS    MP   FG  FGA    FG%   3P  3PA  \
# 0   1     Quincy Acy  PF   24  NYK  68  22  1287  152  331  0.459   18   60
# 1   2   Jordan Adams  SG   20  MEM  30   0   248   35   86  0.407   10   25
# 2   3   Steven Adams   C   21  OKC  70  67  1771  217  399  0.544    0    2
# 3   4    Jeff Adrien  PF   28  MIN  17   0   215   19   44  0.432    0    0
# 4   5  Arron Afflalo  SG   29  TOT  78  72  2502  375  884  0.424  118  333
#
#      3P%   2P  2PA    2P%   eFG%   FT  FTA    FT%  ORB  DRB  TRB  AST  STL  \
# 0  0.300  134  271  0.494  0.486   76   97  0.784   79  222  301   68   27
# 1  0.400   25   61  0.410  0.465   14   23  0.609    9   19   28   16   16
# 2  0.000  217  397  0.547  0.544  103  205  0.502  199  324  523   66   38
# 3  0.000   19   44  0.432  0.432   22   38  0.579   23   54   77   15    4
# 4  0.354  257  551  0.466  0.491  167  198  0.843   27  220  247  129   41
#
# ...

# %%
salaries.isnull().values.any()
# Out:
# False

# %%
salaries.head()
# Out:
#             Team  Season_Start  Season_End  Rk             Player   Salary
# 0  Atlanta Hawks          1990        1991   1       Moses Malone  2406000
# 1  Atlanta Hawks          1990        1991   2  Dominique Wilkins  2065000
# 2  Atlanta Hawks          1990        1991   3         Jon Koncak  1550000
# 3  Atlanta Hawks          1990        1991   4         Doc Rivers   895000
# 4  Atlanta Hawks          1990        1991   5    Rumeal Robinson   800000

# %%
team_change={'ATL':'Atlanta Hawks', 'BOS':'Boston Celtics', 'BRK':'Brooklyn Nets',
       'CHA':'Charlotte Hornets', 'CHI':'Chicago Bulls', 'CLE':'Cleveland Caveliers',
       'DAL':'Dallas Mavericks', 'DEN':'Denver Nuggets', 'DET':'Detroit Pistons',
       'GSW':'Golden State Warriors', 'HOU':'Houston Rockets', 'IND':'Indiana Pacers',
       'LAC':'Los Angeles Clippers', 'LAL':'Los Angeles Lakers', 'MEM':'Memphis Grizzlies',
       'MIA':'Miami Heat', 'MIL':'Milwaukee Bucks', 'MIN':'Minnesota Timberwolves',
       'NOP':'New Orleans Pelicans', 'NYK':'New York Knicks', 'OKC':'Oklahoma City Thunder',
       'ORL':'Orlando Magic', 'PHI':'Philadelphia 76ers', 'PHO':'Phoenix Suns',
       'SAC':'Sacramento Kings', 'SAS':'San Antonio Spurs', 'TOR':'Toronto Raptors',
       'UTA':'Utah Jazz', 'WAS':'Washington Wizards'}

# %%
result=result.replace({"Tm":team_change})

# %%
result=result.rename(columns={"Tm":"Team"})

# %%
result.Team.unique()
# Out:
# array(['New York Knicks', 'Memphis Grizzlies', 'Oklahoma City Thunder',
#        'Minnesota Timberwolves', 'TOT', 'Denver Nuggets', 'POR',
#        'New Orleans Pelicans', 'Philadelphia 76ers', 'Indiana Pacers',
#        'Dallas Mavericks', 'Cleveland Caveliers', 'Miami Heat',
#        'Brooklyn Nets', 'San Antonio Spurs', 'Milwaukee Bucks',
#        'Detroit Pistons', 'Atlanta Hawks', 'Houston Rockets',
#        'Chicago Bulls', 'Golden State Warriors', 'Los Angeles Clippers',
#        'Phoenix Suns', 'Boston Celtics', 'Washington Wizards', 'Utah Jazz',
#        'Sacramento Kings', 'CHO', 'Los Angeles Lakers', 'Toronto Raptors',
#        'Orlando Magic', 'Charlotte Hornets', 'NOH', 'NJN'], dtype=object)

# %%
salaries.Team.unique()
# Out:
# array(['Atlanta Hawks', 'Boston Celtics', 'Brooklyn Nets',
#        'Charlotte Hornets', 'Chicago Bulls', 'Cleveland Caveliers',
#        'Dallas Mavericks', 'Denver Nuggets', 'Detroit Pistons',
#        'Golden State Warriors', 'Houston Rockets', 'Indiana Pacers',
#        'Los Angeles Clippers', 'Los Angeles Lakers', 'Memphis Grizzlies',
#        'Miami Heat', 'Milwaukee Bucks', 'Minnesota Timberwolves',
#        'New Orleans Pelicans', 'New York Knicks', 'Oklahoma City Thunder',
#        'Orlando Magic', 'Philadelphia 76ers', 'Phoenix Suns',
#        'Sacramento Kings', 'San Antonio Spurs', 'Toronto Raptors',
#        'Utah Jazz', 'Washington Wizards'], dtype=object)

# %% [markdown]
# TOT,POR,CHO,NOH are all missing from the salary dataframe. there will be missing values when merged.

# %%
result.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Team', 'G', 'GS', 'MP', 'FG', 'FGA',
#        'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA',
#        'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS',
#        'Year', 'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%',
#        'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/48', 'OBPM',
#        'DBPM', 'BPM', 'VORP', 'ID'],
#       dtype='object')

# %%
salaries.columns
# Out:
# Index(['Team', 'Season_Start', 'Season_End', 'Rk', 'Player', 'Salary'], dtype='object')

# %%
salaries=salaries.rename(columns={"Season_End":"Year","Rk":"Tm_Rk"})

# %%
salary=salaries[(salaries.Year>=2010) & (salaries.Year<=2015)]

# %%
salary.Year.unique()
# Out:
# array([2010, 2011, 2012, 2013, 2014, 2015])

# %%
m1=pd.merge(salary,result,how='left',on=['Player','Team','Year'])

# %%
salary.shape
# Out:
# (2788, 6)

# %%
result.shape
# Out:
# (3575, 52)

# %%
m1.shape
# Out:
# (2788, 55)

# %% [markdown]
# ### Dropping NaN with no salary data available

# %%
m1.isnull().sum()
# Out:
# Team              0
# Season_Start      0
# Year              0
# Tm_Rk             0
# Player            0
# Salary            0
# Rk              410
# Pos             410
# Age             410
# G               410
# GS              410
# MP              410
# FG              410
# FGA             410
# FG%             410
# 3P              410
# 3PA             410
# 3P%             410
# 2P              410
# 2PA             410
# 2P%             410
# eFG%            410
# FT              410
# FTA             410
# FT%             410
# ORB             410
# DRB             410
# TRB             410
# AST             410
# STL             410
# BLK             410
# TOV             410
# PF              410
# PTS             410
# PER             410
# TS%             410
# 3PAr            410
# FTr             410
# ORB%            410
# DRB%            410
# TRB%            410
# AST%            410
# STL%            410
# BLK%            410
# TOV%            410
# ...

# %% [markdown]
# dropping all the NAs because salary15 df have some player salaries missing

# %%
m1.dropna(inplace=True)

# %%
m1.shape
# Out:
# (2378, 55)

# %% [markdown]
# ### Exploratory Data Analysis

# %%
m1.columns
# Out:
# Index(['Team', 'Season_Start', 'Year', 'Tm_Rk', 'Player', 'Salary', 'Rk',
#        'Pos', 'Age', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%',
#        '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB',
#        'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'PER', 'TS%', '3PAr', 'FTr',
#        'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS',
#        'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP', 'ID'],
#       dtype='object')

# %%
sns.pairplot(m1, x_vars=['Age','G','GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%'], y_vars='Salary', size=7, aspect=0.5, kind='reg')

# %%
sns.pairplot(m1, x_vars=['2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB'], y_vars='Salary', size=7, aspect=0.5, kind='reg')

# %%
sns.pairplot(m1, x_vars=['AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'PER', 'TS%', '3PAr', 'FTr'], y_vars='Salary', size=7, aspect=0.5, kind='reg')

# %%
sns.pairplot(m1, x_vars=['ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS'], y_vars='Salary', size=7, aspect=0.5, kind='reg')

# %%
sns.pairplot(m1, x_vars=['DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP'], y_vars='Salary', size=7, aspect=0.5, kind='reg')

# %%
m1.columns
# Out:
# Index(['Team', 'Season_Start', 'Year', 'Tm_Rk', 'Player', 'Salary', 'Rk',
#        'Pos', 'Age', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%',
#        '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB',
#        'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'PER', 'TS%', '3PAr', 'FTr',
#        'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS',
#        'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP', 'ID'],
#       dtype='object')

# %%
correlation_matrix=m1[['Age', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%',
       '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB',
       'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'PER', 'TS%', '3PAr', 'FTr',
       'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS',
       'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP']].corr(method='pearson')
mask = np.zeros_like(correlation_matrix)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(correlation_matrix, cmap='RdYlGn_r', vmax=1.0, vmin=-1.0 , mask = mask, linewidths=2.5)

# %%
def ecdf(data):
    n=len(data)
    x=np.sort(data)
    y=np.arange(1,n+1)/n
    return x,y

# %%
sns.set()

# %%
x,y=ecdf(m1.Salary)
plt.plot(x,y,marker='.',linestyle='none')

# %%
sns.swarmplot(x='Pos',y='Salary',data=m1)

# %%
sns.boxplot(x='Pos',y='Salary',data=m1)

# %%
sns.distplot(m1.Salary)
# Out:
# /home/justin/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.violinplot(m1.Salary)

# %%
m1['GS/G']=m1.GS/m1.G

# %%
sns.regplot(x='GS/G',y='Salary',data=m1)

# %%
m2=m1[m1.G>=20]

# %%
m1.columns
# Out:
# Index(['Team', 'Season_Start', 'Year', 'Tm_Rk', 'Player', 'Salary', 'Rk',
#        'Pos', 'Age', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%',
#        '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB',
#        'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'PER', 'TS%', '3PAr', 'FTr',
#        'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS',
#        'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP', 'ID', 'GS/G'],
#       dtype='object')

# %%
m1.columns
# Out:
# Index(['Team', 'Season_Start', 'Year', 'Tm_Rk', 'Player', 'Salary', 'Rk',
#        'Pos', 'Age', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%',
#        '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB',
#        'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'PER', 'TS%', '3PAr', 'FTr',
#        'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS',
#        'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP', 'ID', 'GS/G'],
#       dtype='object')

# %%
feature_cols=['Age', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%',
       '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB',
       'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'PER', 'TS%', '3PAr', 'FTr',
       'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS',
       'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP']

# %%
feature_cols=['Age','GS','FG','MP','FTA','TRB','AST','STL','BLK','PTS','OWS','VORP']

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
X=m1[feature_cols]
y=m1.Salary
clf=LinearRegression()
scores=cross_val_score(clf,X,y,cv=10,scoring="r2")
print (scores.mean())
# Out:
# 0.466111814619

# %%
from sklearn.model_selection import train_test_split
x_train, x_test,y_train,y_test=train_test_split(X,y)
clf=LinearRegression()
clf.fit(x_train,y_train)
pred=clf.predict(x_test)
np.mean((pred-y_test)**2)
# Out:
# 11545869688650.71

# %%
coeff=pd.DataFrame(X.columns)
coeff['Coefficient_Estimates']=pd.Series(clf.coef_)
coeff['Coefficient_Estimates']=coeff.Coefficient_Estimates.astype(int)
coeff.sort_values('Coefficient_Estimates',ascending=False)
# Out:
#        0  Coefficient_Estimates
# 11  VORP                 782654
# 0    Age                 351277
# 1     GS                  35325
# 2     FG                  15352
# 4    FTA                   9951
# 6    AST                   5387
# 8    BLK                   3605
# 5    TRB                    711
# 9    PTS                    282
# 3     MP                  -2040
# 7    STL                 -37094
# 10   OWS                -368075

# %%
correlation_matrix=m1[['FG%','OWS','BPM','DWS','3PAr','FTr',]].corr(method='pearson')
mask = np.zeros_like(correlation_matrix)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(correlation_matrix, cmap='RdYlGn_r', vmax=1.0, vmin=-1.0 , mask = mask, linewidths=2.5)

# %%
lm.score(x_test,y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-101-9d5856669197> in <module>()
# ----> 1 lm.score(x_test,y_test)
#
# NameError: name 'lm' is not defined

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import linear_model
from sklearn.model_selection import KFold   #For K-fold cross validation
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn import metrics

# %% [markdown]
# instantiate linear regression

# %% [markdown]
# split up into training and testing data, 80/20 split

# %% [markdown]
# fit the data using training dataset

# %% [markdown]
# prediction using testing predictors

# %% [markdown]
# see the coefficients of each predictor variable

# %% [markdown]
# visualizing coefficients via graph

# %% [markdown]
# calculating mean squared error

# %% [markdown]
# plotting residual plot

# %%
# %matplotlib inline

# %%
sns.residplot(pred,(pred-y_test))

# %%
sns.residplot(y_test,(pred-y_test))

# %%
from sklearn.linear_model import Ridge

# %%
clf=Ridge(alpha=0.04,normalize=True)
clf.fit(x_train,y_train)
clf.score(x_test,y_test)

# %%
pred=clf.predict(x_test)
mse=np.mean((pred-y_test)**2)
mse

# %%
from sklearn.linear_model import Lasso

# %%
clf=Lasso(alpha=0.5,normalize=True)
clf.fit(x_train,y_train)
clf.score(x_test,y_test)

# %%
pred=clf.predict(x_test)
mse=np.mean((pred-y_test)**2)
mse

# %%
from sklearn.linear_model import ElasticNet

# %%
clf=ElasticNet(alpha=1, l1_ratio=0.5, normalize=False)
clf.fit(x_train,y_train)
clf.score(x_test,y_test)

# %%
pred=clf.predict(x_test)
mse=np.mean((pred-y_test)**2)
mse

# %%
m2012=m1[m1.Year==2012].copy()

# %%
m2011=m1[m1.Year==2011].copy()

# %%
m2010=m1[m1.Year==2010].copy()

# %%
m2013=m1[m1.Year==2013].copy()

# %%
m2010.loc[:,'Salary_Year_Rank']=m2010.loc[:,'Salary'].rank()

# %%
m2011.loc[:,'Salary_Year_Rank']=m2011.loc[:,'Salary'].rank()

# %%
m2012.loc[:,'Salary_Year_Rank']=m2012.loc[:,'Salary'].rank()

# %%
m2013.loc[:,'Salary_Year_Rank']=m2013.loc[:,'Salary'].rank()

# %%
m2014=m1[m1.Year==2014].copy()

# %%
m2014.loc[:,'Salary_Year_Rank']=m2014.loc[:,'Salary'].rank()

# %%
m2015=m1[m1.Year==2015].copy()

# %%
m2015.loc[:,'Salary_Year_Rank']=m2015.loc[:,'Salary'].rank()

# %%
m2=pd.concat([m2010,m2011,m2012,m2013,m2014,m2015])

# %%
feature_cols=['Age','GS','FG','MP','FTA','TRB','AST','STL','BLK','PTS','OWS','VORP']
X=m2[feature_cols]
y=m2.Salary_Year_Rank
lm=linear_model.LinearRegression()
scores=cross_val_score(lm,X,y,cv=10,scoring="r2")
print (scores.mean())

# %%
feature_cols=['Age','GS','FG','MP','FTA','TRB','AST','STL','BLK','PTS','OWS','VORP']
X=m1[feature_cols]
y=m1.Salary
lm=linear_model.LinearRegression()
scores=cross_val_score(lm,X,y,cv=10,scoring="r2")
print (scores.mean())

# %%
m3=m2[m2.G>=20]

# %%
feature_cols=['Age','GS','FG','MP','FTA','TRB','AST','STL','BLK','PTS','OWS','VORP']
X=m3[feature_cols]
y=m3.Salary
lm=linear_model.LinearRegression()
scores=cross_val_score(lm,X,y,cv=10,scoring="r2")
print (scores.mean())

# %%
m3.columns

# %%
features=['Age', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%',
       '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB',
       'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'PER', 'TS%', '3PAr', 'FTr',
       'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS',
       'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP', 'GS/G']

# %%
from sklearn.metrics import roc_auc_score

# %%
clf=RandomForestRegressor(n_estimators=10,max_features='auto',n_jobs=-1)
clf.fit(x_train,y_train)
clf.score(x_test,y_test)

# %%
df=pd.DataFrame(x_train.columns)
df['Coefficient_Estimates']=pd.Series(clf.feature_importances_)
df.sort_values('Coefficient_Estimates')

# %%
scores=cross_val_score(clf,X,y,cv=10,scoring="r2")
scores.mean()

# %% [markdown]
# use coefficient of determination (R^2) to evaluate results

# %%
from sklearn.grid_search import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
clf = RandomForestRegressor(n_jobs=-1,max_features= 'sqrt' ,n_estimators=50, oob_score = True) 

param_grid = { 
    'n_estimators': [100,200,500,700],
    'max_features': ['auto', 'sqrt', 'log2'],
}

CV_rfc = GridSearchCV(estimator=clf, param_grid=param_grid, cv= 5,scoring='r2')
CV_rfc.fit(X, y)
print (CV_rfc.best_params_)

# %% [markdown]
# random forest, GBM.
# list performance metrics. show coefficients and
